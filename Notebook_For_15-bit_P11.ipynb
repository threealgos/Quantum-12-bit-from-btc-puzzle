# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install qiskit_ibm_runtime && pip install qiskit==0.24.0
# Out:
# Collecting qiskit_ibm_runtime
#   Downloading qiskit_ibm_runtime-0.46.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.32.4)
# Collecting requests-ntlm>=1.1.0 (from qiskit_ibm_runtime)
#   Downloading requests_ntlm-1.3.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.0.2)
# Requirement already satisfied: urllib3>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.9.0.post0)
# Collecting ibm-platform-services>=0.55.3 (from qiskit_ibm_runtime)
#   Downloading ibm_platform_services-0.74.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting ibm-quantum-schemas>=0.5.20260320 (from qiskit_ibm_runtime)
#   Downloading ibm_quantum_schemas-0.5.20260320-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (2.12.3)
# Collecting qiskit>=2.2.0 (from qiskit_ibm_runtime)
#   Downloading qiskit-2.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_runtime) (26.0)
# Collecting pybase64>=1.4 (from qiskit_ibm_runtime)
#   Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (8.7 kB)
# Collecting samplomatic>=0.13.0 (from qiskit_ibm_runtime)
#   Downloading samplomatic-0.17.1-py3-none-any.whl.metadata (6.5 kB)
# Collecting ibm_cloud_sdk_core<4.0.0,>=3.24.4 (from ibm-platform-services>=0.55.3->qiskit_ibm_runtime)
#   Downloading ibm_cloud_sdk_core-3.24.4-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->qiskit_ibm_runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->qiskit_ibm_runtime) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->qiskit_ibm_runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->qiskit_ibm_runtime) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.9.0->qiskit_ibm_runtime) (1.17.0)
# Collecting rustworkx>=0.15.0 (from qiskit>=2.2.0->qiskit_ibm_runtime)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.0->qiskit_ibm_runtime) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.0->qiskit_ibm_runtime) (0.3.8)
# Collecting stevedore>=3.0.0 (from qiskit>=2.2.0->qiskit_ibm_runtime)
#   Downloading stevedore-5.7.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit_ibm_runtime) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit_ibm_runtime) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit_ibm_runtime) (2026.2.25)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit_ibm_runtime) (43.0.3)
# Collecting pyspnego>=0.4.0 (from requests-ntlm>=1.1.0->qiskit_ibm_runtime)
#   Downloading pyspnego-0.12.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from samplomatic>=0.13.0->qiskit_ibm_runtime) (3.11.8)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (2.0.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.55.3->qiskit_ibm_runtime) (2.12.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_runtime) (3.0)
# Downloading qiskit_ibm_runtime-0.46.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.5 MB/s eta 0:00:00
# Downloading ibm_platform_services-0.74.0-py3-none-any.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.8/381.8 kB 25.7 MB/s eta 0:00:00
# Downloading ibm_quantum_schemas-0.5.20260320-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 7.6 MB/s eta 0:00:00
# Downloading pybase64-1.4.3-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.2 MB/s eta 0:00:00
# Downloading qiskit-2.3.1-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 103.0 MB/s eta 0:00:00
# Downloading requests_ntlm-1.3.0-py3-none-any.whl (6.6 kB)
# Downloading samplomatic-0.17.1-py3-none-any.whl (205 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.3/205.3 kB 13.7 MB/s eta 0:00:00
# Downloading ibm_cloud_sdk_core-3.24.4-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.8/75.8 kB 6.1 MB/s eta 0:00:00
# Downloading pyspnego-0.12.1-py3-none-any.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 10.6 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 20.7 MB/s eta 0:00:00
# Downloading stevedore-5.7.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: stevedore, rustworkx, pybase64, qiskit, ibm_cloud_sdk_core, samplomatic, pyspnego, ibm-platform-services, requests-ntlm, ibm-quantum-schemas, qiskit_ibm_runtime
# Successfully installed ibm-platform-services-0.74.0 ibm-quantum-schemas-0.5.20260320 ibm_cloud_sdk_core-3.24.4 pybase64-1.4.3 pyspnego-0.12.1 qiskit-2.3.1 qiskit_ibm_runtime-0.46.1 requests-ntlm-1.3.0 rustworkx-0.17.1 samplomatic-0.17.1 stevedore-5.7.0
# Collecting qiskit==0.24.0
#   Downloading qiskit-0.24.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting qiskit-terra==0.16.4 (from qiskit==0.24.0)
#   Downloading qiskit-terra-0.16.4.tar.gz (8.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 63.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting qiskit-aer==0.7.6 (from qiskit==0.24.0)
#   Downloading qiskit-aer-0.7.6.tar.gz (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 78.5 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install qiskit_ibm_provider && pip install utils && pip install bitarray && pip3 install pandas && pip3 install tolist
# Out:
# Collecting qiskit_ibm_provider
#   Downloading qiskit_ibm_provider-0.11.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: qiskit>=0.45.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_provider) (2.3.1)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_provider) (2.32.4)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_provider) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_provider) (2.0.2)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_provider) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_provider) (2.9.0.post0)
# Requirement already satisfied: websocket-client>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_provider) (1.9.0)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_provider) (15.0.1)
# Requirement already satisfied: typing-extensions>=4.3 in /usr/local/lib/python3.12/dist-packages (from qiskit_ibm_provider) (4.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit_ibm_provider) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.45.0->qiskit_ibm_provider) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.45.0->qiskit_ibm_provider) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.45.0->qiskit_ibm_provider) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.45.0->qiskit_ibm_provider) (5.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->qiskit_ibm_provider) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->qiskit_ibm_provider) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->qiskit_ibm_provider) (2026.2.25)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit_ibm_provider) (43.0.3)
# Requirement already satisfied: pyspnego>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit_ibm_provider) (0.12.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_provider) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_provider) (3.0)
# Downloading qiskit_ibm_provider-0.11.0-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.9/249.9 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: qiskit_ibm_provider
# Successfully installed qiskit_ibm_provider-0.11.0
# Collecting utils
#   Downloading utils-1.0.2.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: utils
#   Building wheel for utils (setup.py) ... done
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13906 sha256=49ef79dbd36eab9d66f699c16cf9d4bb762f2f6a140984dfbb901908f94a8662
#   Stored in directory: /root/.cache/pip/wheels/b6/a1/81/1036477786ae0e17b522f6f5a838f9bc4288d1016fc5d0e1ec
# Successfully built utils
# Installing collected packages: utils
# Successfully installed utils-1.0.2
# Collecting bitarray
#   Downloading bitarray-3.8.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Downloading bitarray-3.8.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.6/343.6 kB 10.4 MB/s eta 0:00:00
# Installing collected packages: bitarray
# Successfully installed bitarray-3.8.1
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting tolist
#   Downloading tolist-0.0.post0.tar.gz (670 bytes)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip3 install qiskit-ibm-runtime --upgrade
# Out:
# Requirement already satisfied: qiskit-ibm-runtime in /usr/local/lib/python3.12/dist-packages (0.46.1)
# Requirement already satisfied: requests>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.32.4)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.0.2)
# Requirement already satisfied: urllib3>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Requirement already satisfied: ibm-platform-services>=0.55.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (0.74.0)
# Requirement already satisfied: ibm-quantum-schemas>=0.5.20260320 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (0.5.20260320)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.12.3)
# Requirement already satisfied: qiskit>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (2.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (26.0)
# Requirement already satisfied: pybase64>=1.4 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (1.4.3)
# Requirement already satisfied: samplomatic>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in /usr/local/lib/python3.12/dist-packages (from ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (3.24.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.9.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (5.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.4->qiskit-ibm-runtime) (2026.2.25)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (43.0.3)
# Requirement already satisfied: pyspnego>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.1)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from samplomatic>=0.13.0->qiskit-ibm-runtime) (3.11.8)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (2.12.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)

# %%
# !pip install \
  guppylang==0.20.* \
  selene-sim==0.2.12 \
  qnexus==0.20.0 --no-deps \
  pytket==2.15.* \
  pytket-quantinuum==0.18.* \
  ecdsa==0.19.* \
  numpy==2.2.6 \
  matplotlib==3.9.* \
  typing-extensions==4.12.*
# Out:
# Collecting guppylang==0.20.*
#   Downloading guppylang-0.20.0-py3-none-any.whl.metadata (15 kB)
# Collecting selene-sim==0.2.12
#   Downloading selene_sim-0.2.12-py3-none-manylinux_2_28_x86_64.whl.metadata (5.9 kB)
# Collecting qnexus==0.20.0
#   Downloading qnexus-0.20.0-py3-none-any.whl.metadata (14 kB)
# Collecting pytket==2.15.*
#   Downloading pytket-2.15.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Collecting pytket-quantinuum==0.18.*
#   Downloading pytket_quantinuum-0.18.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting ecdsa==0.19.*
#   Downloading ecdsa-0.19.2-py2.py3-none-any.whl.metadata (29 kB)
# Collecting numpy==2.2.6
#   Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.8 MB/s eta 0:00:00
# Collecting matplotlib==3.9.*
#   Downloading matplotlib-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting typing-extensions==4.12.*
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Downloading guppylang-0.20.0-py3-none-any.whl (234 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.4/234.4 kB 13.0 MB/s eta 0:00:00
# Downloading selene_sim-0.2.12-py3-none-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 53.7 MB/s eta 0:00:00
# Downloading qnexus-0.20.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.2 MB/s eta 0:00:00
# Downloading pytket-2.15.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 18.8 MB/s eta 0:00:00
# Downloading pytket_quantinuum-0.18.0-py3-none-any.whl (31 kB)
# Downloading ecdsa-0.19.2-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 kB 11.0 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 46.4 MB/s eta 0:00:00
# Downloading matplotlib-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 67.5 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, selene-sim, qnexus, pytket-quantinuum, pytket, numpy, matplotlib, guppylang, ecdsa
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# Successfully installed ecdsa-0.19.2 guppylang-0.20.0 matplotlib-3.9.4 numpy-2.2.6 pytket-2.15.0 pytket-quantinuum-0.18.0 qnexus-0.20.0 selene-sim-0.2.12 typing-extensions-4.12.2

# %%
# !pip install base58 && pip3 install parameters && pip3 install Crypto && pip install pycryptodome && pip install Cryptography && pip install bitcoin && pip install ecdsa && pip3 install bitcoin
# Out:
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl.metadata (3.1 kB)
# Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Installing collected packages: base58
# Successfully installed base58-2.1.1
# Collecting parameters
#   Downloading parameters-0.2.1.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: parameters
#   Building wheel for parameters (setup.py) ... done
#   Created wheel for parameters: filename=parameters-0.2.1-py3-none-any.whl size=24747 sha256=28c035b82f20b0399f3e8316a9b8077bc70176d09cbefad8a549612edc5537bb
#   Stored in directory: /root/.cache/pip/wheels/b6/16/2f/901678771468ce601db89016cf0aa3fbaa690ce3af70b37a1a
# Successfully built parameters
# Installing collected packages: parameters
# Successfully installed parameters-0.2.1
# Collecting Crypto
#   Downloading crypto-1.4.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Collecting Naked (from Crypto)
#   Downloading Naked-0.1.32-py2.py3-none-any.whl.metadata (931 bytes)
# Collecting shellescape (from Crypto)
#   Downloading shellescape-3.8.1-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from Naked->Crypto) (2.32.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from Naked->Crypto) (6.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->Naked->Crypto) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->Naked->Crypto) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->Naked->Crypto) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->Naked->Crypto) (2026.2.25)
# Downloading crypto-1.4.1-py2.py3-none-any.whl (18 kB)
# Downloading Naked-0.1.32-py2.py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 kB 15.4 MB/s eta 0:00:00
# Downloading shellescape-3.8.1-py2.py3-none-any.whl (3.1 kB)
# Installing collected packages: shellescape, Naked, Crypto
# Successfully installed Crypto-1.4.1 Naked-0.1.32 shellescape-3.8.1
# Collecting pycryptodome
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 36.3 MB/s eta 0:00:00
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.23.0
# Requirement already satisfied: Cryptography in /usr/local/lib/python3.12/dist-packages (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from Cryptography) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->Cryptography) (3.0)
# Collecting bitcoin
#   Downloading bitcoin-1.1.42.tar.gz (36 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: bitcoin
#   Building wheel for bitcoin (setup.py) ... done
#   Created wheel for bitcoin: filename=bitcoin-1.1.42-py3-none-any.whl size=44403 sha256=61da2221e372281be8d00bfb0a8ff5b9a0c40d871fb7fa3b416143d472f0c729
#   Stored in directory: /root/.cache/pip/wheels/ca/58/57/229b3e0dacbfd900c21be9010d6b138ec314fe91f57e973183
# Successfully built bitcoin
# Installing collected packages: bitcoin
# Successfully installed bitcoin-1.1.42
# Requirement already satisfied: ecdsa in /usr/local/lib/python3.12/dist-packages (0.19.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from ecdsa) (1.17.0)
# Requirement already satisfied: bitcoin in /usr/local/lib/python3.12/dist-packages (1.1.42)

# %%
# !pip3 install bit && pip3 install ice && pip3 install argparse && pip3 install pub && pip3 install requests && pip3 install ctypes
# Out:
# Collecting bit
#   Downloading bit-0.8.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting coincurve>=4.3.0 (from bit)
#   Downloading coincurve-21.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bit) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bit) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bit) (2026.2.25)
# Downloading bit-0.8.0-py3-none-any.whl (68 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.9/68.9 kB 2.8 MB/s eta 0:00:00
# Downloading coincurve-21.0.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.8 MB/s eta 0:00:00
# Installing collected packages: coincurve, bit
# Successfully installed bit-0.8.0 coincurve-21.0.0
# Collecting ice
#   Downloading ice-0.0.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ice
#   Building wheel for ice (setup.py) ... done
#   Created wheel for ice: filename=ice-0.0.2-py3-none-any.whl size=11664 sha256=b4d70e5658f513a33add3d275be29d35a926920656d58200a82cfe642f84a1fb
#   Stored in directory: /root/.cache/pip/wheels/47/ab/d4/d73ad9aae95714c1c1a0778b6a469216f15d68d89f2e93605b
# Successfully built ice
# Installing collected packages: ice
# Successfully installed ice-0.0.2
# Collecting argparse
#   Downloading argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Collecting pub
#   Downloading pub-0.0.4.tar.gz (6.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting path.py>=2.2 (from pub)
#   Downloading path.py-12.5.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting envoy>=0.0.2 (from pub)
#   Downloading envoy-0.0.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: networkx>=1.6 in /usr/local/lib/python3.12/dist-packages (from pub) (3.6.1)
# Collecting path (from path.py>=2.2->pub)
#   Downloading path-17.1.1-py3-none-any.whl.metadata (6.5 kB)
# Downloading envoy-0.0.3-py2.py3-none-any.whl (5.0 kB)
# Downloading path.py-12.5.0-py3-none-any.whl (2.3 kB)
# Downloading path-17.1.1-py3-none-any.whl (23 kB)
# Building wheels for collected packages: pub
#   Building wheel for pub (setup.py) ... done
#   Created wheel for pub: filename=pub-0.0.4-py3-none-any.whl size=5627 sha256=e2cbbbb59754d480145288a421276f3e21a296f5c38903aa0975fa583d80fe1c
#   Stored in directory: /root/.cache/pip/wheels/cf/09/50/66135bec71213e047fafb802c784d719b7cfd91240250d5e0d
# Successfully built pub
# Installing collected packages: envoy, path, path.py, pub
# Successfully installed envoy-0.0.3 path-17.1.1 path.py-12.5.0 pub-0.0.4
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.2.25)
# ERROR: Could not find a version that satisfies the requirement ctypes (from versions: none)
# ERROR: No matching distribution found for ctypes

# %%
# !pip3 install qiskit.algorithms
# Out:
# Collecting qiskit.algorithms
#   Downloading qiskit_algorithms-0.4.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: qiskit>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit.algorithms) (2.3.1)
# Requirement already satisfied: scipy>=1.4 in /usr/local/lib/python3.12/dist-packages (from qiskit.algorithms) (1.16.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from qiskit.algorithms) (2.2.6)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.0->qiskit.algorithms) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.0->qiskit.algorithms) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.0->qiskit.algorithms) (5.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.0->qiskit.algorithms) (4.12.2)
# Downloading qiskit_algorithms-0.4.0-py3-none-any.whl (327 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.8/327.8 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: qiskit.algorithms
# Successfully installed qiskit.algorithms-0.4.0

# %%
# !pip install qiskit-Aer
# Out:
# Collecting qiskit-Aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Requirement already satisfied: qiskit>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (2.3.1)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (2.2.6)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (1.16.3)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from qiskit-Aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.0->qiskit-Aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (5.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=1.1.0->qiskit-Aer) (4.12.2)
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 49.7 MB/s eta 0:00:00
# Installing collected packages: qiskit-Aer
# Successfully installed qiskit-Aer-0.17.2

# %%
# !pip3 install -U qiskit
# Out:
# Requirement already satisfied: qiskit in /usr/local/lib/python3.12/dist-packages (2.3.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /usr/local/lib/python3.12/dist-packages (from qiskit) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit) (5.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit) (4.12.2)

# %%
# !pip3 install pylatexenc
# Out:
# Collecting pylatexenc
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=51c4f3119bd223c6c2353e5dedcd565ac6409d787b14aeca998109a65e84069e
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10

# %%
# !pip3 install qiskit_utils
# Out:
# Collecting qiskit_utils
#   Downloading qiskit_utils-1.2.1.tar.gz (4.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: qiskit>=0.34.2 in /usr/local/lib/python3.12/dist-packages (from qiskit_utils) (2.3.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (5.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit_utils) (4.12.2)
# Building wheels for collected packages: qiskit_utils
#   Building wheel for qiskit_utils (setup.py) ... done
#   Created wheel for qiskit_utils: filename=qiskit_utils-1.2.1-py3-none-any.whl size=6544 sha256=8e59a287001dc6a225eca37d56bc2e08a8e66553886d15741dd3e9e3e97ebeac
#   Stored in directory: /root/.cache/pip/wheels/d5/69/28/dd4cc85e74d17a26804ac573c8ee9b750413a274f8f7a378d8
# Successfully built qiskit_utils
# Installing collected packages: qiskit_utils
# Successfully installed qiskit_utils-1.2.1

# %%
# !pip3 install qiskit.utils
# Out:
# Requirement already satisfied: qiskit.utils in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: qiskit>=0.34.2 in /usr/local/lib/python3.12/dist-packages (from qiskit.utils) (2.3.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (2.2.6)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (0.3.8)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (5.7.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from qiskit>=0.34.2->qiskit.utils) (4.12.2)

# %%
# !pip3 install synthesis && pip3 install period
# Out:
# Collecting synthesis
#   Downloading synthesis-1.1061.tar.gz (629 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 629.6/629.6 kB 14.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from synthesis) (75.2.0)
# Building wheels for collected packages: synthesis
#   Building wheel for synthesis (setup.py) ... done
#   Created wheel for synthesis: filename=synthesis-1.1061-py3-none-any.whl size=241849 sha256=c667d0e6ae88fca6f07c45b398b5838673cedd0bd4526be2e5d22f9df5ac5c00
#   Stored in directory: /root/.cache/pip/wheels/80/21/4c/70e79ff149a83083640bbd7e2ff920b8c7e7801475e526b453
# Successfully built synthesis
# Installing collected packages: synthesis
# Successfully installed synthesis-1.1061
# Collecting period
#   Downloading period-0.6.1.tar.gz (8.4 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip3 install helios && pip3 install fpylll
# Out:
# Collecting helios
#   Downloading helios-0.3.0-py3-none-any.whl.metadata (5.4 kB)
# Downloading helios-0.3.0-py3-none-any.whl (29 kB)
# Installing collected packages: helios
# Successfully installed helios-0.3.0
# Collecting fpylll
#   Downloading fpylll-0.6.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Downloading fpylll-0.6.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 MB 11.9 MB/s eta 0:00:00
# Installing collected packages: fpylll
# Successfully installed fpylll-0.6.4

# %%
# !pip3 install -e && pip3 install -e .
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# -e option requires 1 argument

# %%
# !pip3 install tket2-exts~=0.6.0 && pip3 install graphviz<0.21 && pip3 install hugr~=0.11.5 && pip3 install selene-hugr-qis-compiler~=0.2.6 && pip3 install quantinuum-schemas<8.0,>=7.5.0 && pip3 install nest-asyncio2<2.0,>=1.6
# Out:
# Collecting tket2-exts~=0.6.0
#   Downloading tket2_exts-0.6.0-py3-none-any.whl.metadata (15 kB)
# Collecting hugr~=0.11.1 (from tket2-exts~=0.6.0)
#   Downloading hugr-0.11.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.11.1->tket2-exts~=0.6.0) (0.21)
# Collecting pydantic<2.12,>=2.8 (from hugr~=0.11.1->tket2-exts~=0.6.0)
#   Downloading pydantic-2.11.10-py3-none-any.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 3.8 MB/s eta 0:00:00
# Collecting pydantic-extra-types>=2.9.0 (from hugr~=0.11.1->tket2-exts~=0.6.0)
#   Downloading pydantic_extra_types-2.11.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting semver>=3.0.2 (from hugr~=0.11.1->tket2-exts~=0.6.0)
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.11.1->tket2-exts~=0.6.0) (4.12.2)
# Collecting pyzstd~=0.16.2 (from hugr~=0.11.1->tket2-exts~=0.6.0)
#   Downloading pyzstd-0.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.11.1->tket2-exts~=0.6.0) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.8->hugr~=0.11.1->tket2-exts~=0.6.0)
#   Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.11.1->tket2-exts~=0.6.0) (0.4.2)
# Downloading tket2_exts-0.6.0-py3-none-any.whl (17 kB)
# Downloading hugr-0.11.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (598 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.6/598.6 kB 20.6 MB/s eta 0:00:00
# Downloading pydantic-2.11.10-py3-none-any.whl (444 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.8/444.8 kB 26.3 MB/s eta 0:00:00
# Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 58.9 MB/s eta 0:00:00
# Downloading pydantic_extra_types-2.11.1-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.9 MB/s eta 0:00:00
# Downloading pyzstd-0.16.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (414 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.6/414.6 kB 27.5 MB/s eta 0:00:00
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Installing collected packages: semver, pyzstd, pydantic-core, pydantic, pydantic-extra-types, hugr, tket2-exts
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.41.4
#     Uninstalling pydantic_core-2.41.4:
#       Successfully uninstalled pydantic_core-2.41.4
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.3
#     Uninstalling pydantic-2.12.3:
#       Successfully uninstalled pydantic-2.12.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, which is not installed.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# guppylang 0.20.0 requires graphviz<0.21,>=0.20.1, but you have graphviz 0.21 which is incompatible.
# guppylang 0.20.0 requires hugr~=0.12.1, but you have hugr 0.11.5 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.6.0 which is incompatible.
# google-genai 1.68.0 requires typing-extensions<5.0.0,>=4.14.0, but you have typing-extensions 4.12.2 which is incompatible.
# openai 2.30.0 requires typing-extensions<5,>=4.14, but you have typing-extensions 4.12.2 which is incompatible.
# google-adk 1.28.0 requires pydantic<3.0.0,>=2.12.0, but you have pydantic 2.11.10 which is incompatible.
# Successfully installed hugr-0.11.5 pydantic-2.11.10 pydantic-core-2.33.2 pydantic-extra-types-2.11.1 pyzstd-0.16.2 semver-3.0.4 tket2-exts-0.6.0
# /bin/bash: line 1: 0.21: No such file or directory

# %%
# !pip install qwasm && pip install quantinuum_schemas
# Out:
# Collecting qwasm
#   Downloading qwasm-1.0.1-py3-none-any.whl.metadata (299 bytes)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from qwasm) (75.2.0)
# Downloading qwasm-1.0.1-py3-none-any.whl (15 kB)
# Installing collected packages: qwasm
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, which is not installed.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# Successfully installed qwasm-1.0.1
# Collecting quantinuum_schemas
#   Downloading quantinuum_schemas-7.6.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.10.18 in /usr/local/lib/python3.12/dist-packages (from quantinuum_schemas) (3.11.8)
# Requirement already satisfied: pydantic-extra-types<3.0.0,>=2.10.5 in /usr/local/lib/python3.12/dist-packages (from quantinuum_schemas) (2.11.1)
# Requirement already satisfied: pydantic<3,>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from quantinuum_schemas) (2.11.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6.0->quantinuum_schemas) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6.0->quantinuum_schemas) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6.0->quantinuum_schemas) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.6.0->quantinuum_schemas) (0.4.2)
# Downloading quantinuum_schemas-7.6.0-py3-none-any.whl (26 kB)
# Installing collected packages: quantinuum_schemas
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.6.0 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# Successfully installed quantinuum_schemas-7.6.0

# %%
# !pip3 install pyyaml && pip3 install selene-core && pip3 install selene-hugr-qis-compiler && pip3 install tqdm && pip3 install msal~=1.18 && pip3 install types-requests && pip3 install pytket~=1.17 && pip3 install quantinuum-schemas<4.0,>=3.2.3 && pip3 install websockets<14,>11 && pip3 install pydantic<3.0.0,>=2.12.0
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (6.0.3)
# Collecting selene-core
#   Downloading selene_core-0.2.6-py3-none-any.whl.metadata (1.8 kB)
# Collecting hugr>=0.13.0 (from selene-core)
#   Downloading hugr-0.16.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting lief>=0.16.5 (from selene-core)
#   Downloading lief-0.17.6-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: networkx<4,>=2.6 in /usr/local/lib/python3.12/dist-packages (from selene-core) (3.6.1)
# Requirement already satisfied: pydot>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from selene-core) (4.0.1)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from selene-core) (6.0.3)
# Collecting qir-qis>=0.1.1 (from selene-core)
#   Downloading qir_qis-0.1.4-cp310-abi3-manylinux_2_34_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.12/dist-packages (from selene-core) (4.12.2)
# Collecting ziglang~=0.13 (from selene-core)
#   Downloading ziglang-0.15.2-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.musllinux_1_1_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from hugr>=0.13.0->selene-core) (0.21)
# Requirement already satisfied: pydantic~=2.8 in /usr/local/lib/python3.12/dist-packages (from hugr>=0.13.0->selene-core) (2.11.10)
# Requirement already satisfied: pydantic-extra-types~=2.9 in /usr/local/lib/python3.12/dist-packages (from hugr>=0.13.0->selene-core) (2.11.1)
# Requirement already satisfied: semver~=3.0 in /usr/local/lib/python3.12/dist-packages (from hugr>=0.13.0->selene-core) (3.0.4)
# Requirement already satisfied: pyparsing>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pydot>=4.0.0->selene-core) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.8->hugr>=0.13.0->selene-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.8->hugr>=0.13.0->selene-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.8->hugr>=0.13.0->selene-core) (0.4.2)
# Downloading selene_core-0.2.6-py3-none-any.whl (29 kB)
# Downloading hugr-0.16.0-cp310-abi3-manylinux_2_28_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 50.8 MB/s eta 0:00:00
# Downloading lief-0.17.6-cp312-cp312-manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 62.0 MB/s eta 0:00:00
# Downloading qir_qis-0.1.4-cp310-abi3-manylinux_2_34_x86_64.whl (26.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 40.9 MB/s eta 0:00:00
# Downloading ziglang-0.15.2-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.musllinux_1_1_x86_64.whl (93.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 MB 8.8 MB/s eta 0:00:00
# Installing collected packages: ziglang, qir-qis, lief, hugr, selene-core
#   Attempting uninstall: hugr
#     Found existing installation: hugr 0.11.5
#     Uninstalling hugr-0.11.5:
#       Successfully uninstalled hugr-0.11.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# selene-sim 0.2.12 requires selene-hugr-qis-compiler~=0.2.6, which is not installed.
# tket2-exts 0.6.0 requires hugr~=0.11.1, but you have hugr 0.16.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.6.0 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# guppylang 0.20.0 requires graphviz<0.21,>=0.20.1, but you have graphviz 0.21 which is incompatible.
# guppylang 0.20.0 requires hugr~=0.12.1, but you have hugr 0.16.0 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.6.0 which is incompatible.
# Successfully installed hugr-0.16.0 lief-0.17.6 qir-qis-0.1.4 selene-core-0.2.6 ziglang-0.15.2
# Collecting selene-hugr-qis-compiler
#   Downloading selene_hugr_qis_compiler-0.2.10-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Downloading selene_hugr_qis_compiler-0.2.10-cp310-abi3-manylinux_2_28_x86_64.whl (34.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.0/34.0 MB 13.7 MB/s eta 0:00:00
# Installing collected packages: selene-hugr-qis-compiler
# Successfully installed selene-hugr-qis-compiler-0.2.10
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Collecting msal~=1.18
#   Downloading msal-1.35.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from msal~=1.18) (2.32.4)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal~=1.18) (2.12.1)
# Requirement already satisfied: cryptography<49,>=2.5 in /usr/local/lib/python3.12/dist-packages (from msal~=1.18) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<49,>=2.5->msal~=1.18) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->msal~=1.18) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->msal~=1.18) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->msal~=1.18) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->msal~=1.18) (2026.2.25)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<49,>=2.5->msal~=1.18) (3.0)
# Downloading msal-1.35.1-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: msal
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket-quantinuum 0.18.0 requires types-requests, which is not installed.
# pytket-quantinuum 0.18.0 requires pytket~=1.17, but you have pytket 2.15.0 which is incompatible.
# Successfully installed msal-1.35.1
# Collecting types-requests
#   Downloading types_requests-2.33.0.20260402-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: urllib3>=2 in /usr/local/lib/python3.12/dist-packages (from types-requests) (2.6.3)
# Downloading types_requests-2.33.0.20260402-py3-none-any.whl (20 kB)
# Installing collected packages: types-requests
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket-quantinuum 0.18.0 requires pytket~=1.17, but you have pytket 2.15.0 which is incompatible.
# Successfully installed types-requests-2.33.0.20260402
# Collecting pytket~=1.17
#   Downloading pytket-1.41.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: sympy>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from pytket~=1.17) (1.14.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from pytket~=1.17) (2.2.6)
# Requirement already satisfied: lark>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from pytket~=1.17) (1.3.1)
# Requirement already satisfied: scipy>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from pytket~=1.17) (1.16.3)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from pytket~=1.17) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from pytket~=1.17) (0.21)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from pytket~=1.17) (3.1.6)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pytket~=1.17) (4.12.2)
# Requirement already satisfied: qwasm>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pytket~=1.17) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.4->pytket~=1.17) (3.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from qwasm>=1.0.1->pytket~=1.17) (75.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.12.1->pytket~=1.17) (1.3.0)
# Downloading pytket-1.41.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 11.0 MB/s eta 0:00:00
# Installing collected packages: pytket
#   Attempting uninstall: pytket
#     Found existing installation: pytket 2.15.0
#     Uninstalling pytket-2.15.0:
#       Successfully uninstalled pytket-2.15.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.6.0 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# Successfully installed pytket-1.41.0
# /bin/bash: line 1: 4.0,: No such file or directory

# %%
# !pip show selene-sim
# Out:
# Name: selene-sim
# Version: 0.2.12
# Summary: Quantinuum's open source emulator for hybrid quantum computation
# Home-page:
# Author:
# Author-email: Jake Arkinstall <jake.arkinstall@quantinuum.com>, TKET development team <tket-support@quantinuum.com>
# License:
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: numpy, pyyaml, selene-core, selene-hugr-qis-compiler, tqdm
# Required-by:

# %%
import selene_sim
print(dir(selene_sim))  # list all exported names
# Out:
# ['BitcodeString', 'BuildMethod', 'CircuitExtractor', 'ClassicalReplay', 'Coinflip', 'DepolarizingErrorModel', 'EventHook', 'HeliosInterface', 'IdealErrorModel', 'MeasurementExtractor', 'MetricStore', 'MultiEventHook', 'NoEventHook', 'QuantumReplay', 'Quest', 'SeleneInstance', 'SimpleLeakageErrorModel', 'SimpleRuntime', 'SoftRZRuntime', 'Stim', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'backends', 'build', 'dist_dir', 'event_hooks', 'exceptions', 'instance', 'pathlib', 'process', 'result_handling', 'timeout']

# %%
# !pip3 install tket2-exts~=0.8.0 && pip3 install graphviz~=0.20.1 && pip3 install hugr~=0.13.1 && pip3 install selene-hugr-qis-compiler~=0.2.6 && pip3 install quantinuum-schemas<4.0,>=3.2.3 && pip3 install websockets<14,>11 && pip3 install nest-asyncio2
# Out:
# Collecting tket2-exts~=0.8.0
#   Downloading tket2_exts-0.8.0-py3-none-any.whl.metadata (15 kB)
# Collecting hugr~=0.12.0 (from tket2-exts~=0.8.0)
#   Downloading hugr-0.12.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (0.21)
# Requirement already satisfied: pydantic<2.12,>=2.8 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (2.11.10)
# Requirement already satisfied: pydantic-extra-types>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (2.11.1)
# Requirement already satisfied: semver>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (3.0.4)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (4.12.2)
# Requirement already satisfied: pyzstd<0.18.0,>=0.16.2 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (0.16.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (0.4.2)
# Downloading tket2_exts-0.8.0-py3-none-any.whl (18 kB)
# Downloading hugr-0.12.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (603 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.5/603.5 kB 11.8 MB/s eta 0:00:00
# Installing collected packages: hugr, tket2-exts
#   Attempting uninstall: hugr
#     Found existing installation: hugr 0.16.0
#     Uninstalling hugr-0.16.0:
#       Successfully uninstalled hugr-0.16.0
#   Attempting uninstall: tket2-exts
#     Found existing installation: tket2-exts 0.6.0
#     Uninstalling tket2-exts-0.6.0:
#       Successfully uninstalled tket2-exts-0.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.6.0 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# guppylang 0.20.0 requires graphviz<0.21,>=0.20.1, but you have graphviz 0.21 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.8.0 which is incompatible.
# selene-core 0.2.6 requires hugr>=0.13.0, but you have hugr 0.12.5 which is incompatible.
# Successfully installed hugr-0.12.5 tket2-exts-0.8.0
# Collecting graphviz~=0.20.1
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: graphviz
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.21
#     Uninstalling graphviz-0.21:
#       Successfully uninstalled graphviz-0.21
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.6.0 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.8.0 which is incompatible.
# selene-core 0.2.6 requires hugr>=0.13.0, but you have hugr 0.12.5 which is incompatible.
# google-adk 1.28.0 requires pydantic<3.0.0,>=2.12.0, but you have pydantic 2.11.10 which is incompatible.
# Successfully installed graphviz-0.20.3
# Collecting hugr~=0.13.1
#   Downloading hugr-0.13.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.13.1) (0.20.3)
# Requirement already satisfied: pydantic<2.12,>=2.8 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.13.1) (2.11.10)
# Requirement already satisfied: pydantic-extra-types>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.13.1) (2.11.1)
# Requirement already satisfied: semver>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.13.1) (3.0.4)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.13.1) (4.12.2)
# Requirement already satisfied: pyzstd<0.18.0,>=0.16.2 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.13.1) (0.16.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.13.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.13.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.13.1) (0.4.2)
# Downloading hugr-0.13.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.7/612.7 kB 15.9 MB/s eta 0:00:00
# Installing collected packages: hugr
#   Attempting uninstall: hugr
#     Found existing installation: hugr 0.12.5
#     Uninstalling hugr-0.12.5:
#       Successfully uninstalled hugr-0.12.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tket2-exts 0.8.0 requires hugr~=0.12.0, but you have hugr 0.13.1 which is incompatible.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.6.0 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# guppylang 0.20.0 requires hugr~=0.12.1, but you have hugr 0.13.1 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.8.0 which is incompatible.
# Successfully installed hugr-0.13.1
# Requirement already satisfied: selene-hugr-qis-compiler~=0.2.6 in /usr/local/lib/python3.12/dist-packages (0.2.10)
# /bin/bash: line 1: 4.0,: No such file or directory

# %%
# !pip3 install tket2-exts~=0.8.0 && pip3 install quantinuum-schemas~=4.0 && pip3 install pytket~=2.3.1 && pip3 install tket2-exts~=0.9.1 && pip3 install quantinuum-schemas~=3.2.3 && pip3 install colorama
# Out:
# Requirement already satisfied: tket2-exts~=0.8.0 in /usr/local/lib/python3.12/dist-packages (0.8.0)
# Collecting hugr~=0.12.0 (from tket2-exts~=0.8.0)
#   Using cached hugr-0.12.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (0.20.3)
# Requirement already satisfied: pydantic<2.12,>=2.8 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (2.11.10)
# Requirement already satisfied: pydantic-extra-types>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (2.11.1)
# Requirement already satisfied: semver>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (3.0.4)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (4.12.2)
# Requirement already satisfied: pyzstd<0.18.0,>=0.16.2 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.8.0) (0.16.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.8.0) (0.4.2)
# Using cached hugr-0.12.5-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (603 kB)
# Installing collected packages: hugr
#   Attempting uninstall: hugr
#     Found existing installation: hugr 0.13.1
#     Uninstalling hugr-0.13.1:
#       Successfully uninstalled hugr-0.13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 7.6.0 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# guppylang 0.20.0 requires tket2-exts~=0.9.1, but you have tket2-exts 0.8.0 which is incompatible.
# selene-core 0.2.6 requires hugr>=0.13.0, but you have hugr 0.12.5 which is incompatible.
# Successfully installed hugr-0.12.5
# Collecting quantinuum-schemas~=4.0
#   Downloading quantinuum_schemas-4.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.10.18 in /usr/local/lib/python3.12/dist-packages (from quantinuum-schemas~=4.0) (3.11.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from quantinuum-schemas~=4.0) (2.11.10)
# Requirement already satisfied: pydantic-extra-types<3.0.0,>=2.10.5 in /usr/local/lib/python3.12/dist-packages (from quantinuum-schemas~=4.0) (2.11.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=4.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=4.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=4.0) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=4.0) (0.4.2)
# Downloading quantinuum_schemas-4.0.0-py3-none-any.whl (15 kB)
# Installing collected packages: quantinuum-schemas
#   Attempting uninstall: quantinuum-schemas
#     Found existing installation: quantinuum-schemas 7.6.0
#     Uninstalling quantinuum-schemas-7.6.0:
#       Successfully uninstalled quantinuum-schemas-7.6.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires pytket<3.0,>=2.3.1, but you have pytket 1.41.0 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 4.0.0 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# Successfully installed quantinuum-schemas-4.0.0
# Collecting pytket~=2.3.1
#   Downloading pytket-2.3.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: sympy>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from pytket~=2.3.1) (1.14.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from pytket~=2.3.1) (2.2.6)
# Requirement already satisfied: lark>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from pytket~=2.3.1) (1.3.1)
# Requirement already satisfied: scipy>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from pytket~=2.3.1) (1.16.3)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from pytket~=2.3.1) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from pytket~=2.3.1) (0.20.3)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from pytket~=2.3.1) (3.1.6)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pytket~=2.3.1) (4.12.2)
# Requirement already satisfied: qwasm>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pytket~=2.3.1) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.4->pytket~=2.3.1) (3.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from qwasm>=1.0.1->pytket~=2.3.1) (75.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.12.1->pytket~=2.3.1) (1.3.0)
# Downloading pytket-2.3.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 12.6 MB/s eta 0:00:00
# Installing collected packages: pytket
#   Attempting uninstall: pytket
#     Found existing installation: pytket 1.41.0
#     Uninstalling pytket-1.41.0:
#       Successfully uninstalled pytket-1.41.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pytket-quantinuum 0.18.0 requires pytket~=1.17, but you have pytket 2.3.2 which is incompatible.
# qnexus 0.20.0 requires quantinuum-schemas<4.0,>=3.2.3, but you have quantinuum-schemas 4.0.0 which is incompatible.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# Successfully installed pytket-2.3.2
# Collecting tket2-exts~=0.9.1
#   Downloading tket2_exts-0.9.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: hugr~=0.12.0 in /usr/local/lib/python3.12/dist-packages (from tket2-exts~=0.9.1) (0.12.5)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (0.20.3)
# Requirement already satisfied: pydantic<2.12,>=2.8 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (2.11.10)
# Requirement already satisfied: pydantic-extra-types>=2.9.0 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (2.11.1)
# Requirement already satisfied: semver>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (3.0.4)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (4.12.2)
# Requirement already satisfied: pyzstd<0.18.0,>=0.16.2 in /usr/local/lib/python3.12/dist-packages (from hugr~=0.12.0->tket2-exts~=0.9.1) (0.16.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.9.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.9.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.12,>=2.8->hugr~=0.12.0->tket2-exts~=0.9.1) (0.4.2)
# Downloading tket2_exts-0.9.2-py3-none-any.whl (18 kB)
# Installing collected packages: tket2-exts
#   Attempting uninstall: tket2-exts
#     Found existing installation: tket2-exts 0.8.0
#     Uninstalling tket2-exts-0.8.0:
#       Successfully uninstalled tket2-exts-0.8.0
# Successfully installed tket2-exts-0.9.2
# Collecting quantinuum-schemas~=3.2.3
#   Downloading quantinuum_schemas-3.2.6-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: orjson<4.0.0,>=3.10.18 in /usr/local/lib/python3.12/dist-packages (from quantinuum-schemas~=3.2.3) (3.11.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.0 in /usr/local/lib/python3.12/dist-packages (from quantinuum-schemas~=3.2.3) (2.11.10)
# Requirement already satisfied: pydantic-extra-types<3.0.0,>=2.10.5 in /usr/local/lib/python3.12/dist-packages (from quantinuum-schemas~=3.2.3) (2.11.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=3.2.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=3.2.3) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=3.2.3) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.6.0->quantinuum-schemas~=3.2.3) (0.4.2)
# Downloading quantinuum_schemas-3.2.6-py3-none-any.whl (15 kB)
# Installing collected packages: quantinuum-schemas
#   Attempting uninstall: quantinuum-schemas
#     Found existing installation: quantinuum-schemas 4.0.0
#     Uninstalling quantinuum-schemas-4.0.0:
#       Successfully uninstalled quantinuum-schemas-4.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# Successfully installed quantinuum-schemas-3.2.6
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (0.4.6)

# %%
# !pip3 install pytket-quantinuum==0.56.2 && pip3 install pytket --upgrade
# Out:
# Collecting pytket-quantinuum==0.56.2
#   Downloading pytket_quantinuum-0.56.2-py3-none-any.whl.metadata (4.9 kB)
# Collecting pytket>=2.9.3 (from pytket-quantinuum==0.56.2)
#   Downloading pytket-2.16.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Collecting pytket-qir>=0.25.0 (from pytket-quantinuum==0.56.2)
#   Downloading pytket_qir-1.0.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from pytket-quantinuum==0.56.2) (2.2.6)
# Requirement already satisfied: sympy>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.14.0)
# Requirement already satisfied: lark>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.3.1)
# Requirement already satisfied: scipy>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.16.3)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (0.20.3)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (3.1.6)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (4.12.2)
# Requirement already satisfied: qwasm>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.0.1)
# Collecting pyqir~=0.11.1 (from pytket-qir>=0.25.0->pytket-quantinuum==0.56.2)
#   Downloading pyqir-0.11.1-cp39-abi3-manylinux_2_34_x86_64.manylinux_2_35_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.4->pytket>=2.9.3->pytket-quantinuum==0.56.2) (3.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from qwasm>=1.0.1->pytket>=2.9.3->pytket-quantinuum==0.56.2) (75.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.12.1->pytket>=2.9.3->pytket-quantinuum==0.56.2) (1.3.0)
# Downloading pytket_quantinuum-0.56.2-py3-none-any.whl (27 kB)
# Downloading pytket-2.16.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 46.1 MB/s eta 0:00:00
# Downloading pytket_qir-1.0.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.2 MB/s eta 0:00:00
# Downloading pyqir-0.11.1-cp39-abi3-manylinux_2_34_x86_64.manylinux_2_35_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 35.7 MB/s eta 0:00:00
# Installing collected packages: pyqir, pytket, pytket-qir, pytket-quantinuum
#   Attempting uninstall: pytket
#     Found existing installation: pytket 2.3.2
#     Uninstalling pytket-2.3.2:
#       Successfully uninstalled pytket-2.3.2
#   Attempting uninstall: pytket-quantinuum
#     Found existing installation: pytket-quantinuum 0.18.0
#     Uninstalling pytket-quantinuum-0.18.0:
#       Successfully uninstalled pytket-quantinuum-0.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# qnexus 0.20.0 requires websockets<14,>11, but you have websockets 15.0.1 which is incompatible.
# Successfully installed pyqir-0.11.1 pytket-2.16.0 pytket-qir-1.0.0 pytket-quantinuum-0.56.2
# Requirement already satisfied: pytket in /usr/local/lib/python3.12/dist-packages (2.16.0)
# Requirement already satisfied: sympy>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from pytket) (1.14.0)
# Requirement already satisfied: numpy>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from pytket) (2.2.6)
# Requirement already satisfied: lark>=1.1.9 in /usr/local/lib/python3.12/dist-packages (from pytket) (1.3.1)
# Requirement already satisfied: scipy>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from pytket) (1.16.3)
# Requirement already satisfied: networkx>=2.8.8 in /usr/local/lib/python3.12/dist-packages (from pytket) (3.6.1)
# Requirement already satisfied: graphviz>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from pytket) (0.20.3)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from pytket) (3.1.6)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pytket) (4.12.2)
# Requirement already satisfied: qwasm>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from pytket) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.4->pytket) (3.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from qwasm>=1.0.1->pytket) (75.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.12.1->pytket) (1.3.0)

# %%
# !cd /content/drive/MyDrive/ && git clone https://github.com/ibm022023/Quantum-12-bit-from-btc-puzzle.git
# Out:
# Cloning into 'Quantum-12-bit-from-btc-puzzle'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 33 (delta 16), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 71.12 KiB | 3.74 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# !python -c "import guppylang; import selene_sim; import qnexus; import pytket; import ecdsa; import numpy; print('All core imports OK')"
# Out:
# All core imports OK

# %%
# !cd /content/drive/MyDrive/Quantum-12-bit-from-btc-puzzle/ && python3 15-bit-from-P11-List.py
# Out:
# ============================================================================================================================================
# BITCOIN PUZZLE #15 - ULTIMATE PURE SHOR'S STYLE QUANTUM ECDLP SOLVER
# No lower bits method - full recovery from public key only
# ZNE REMOVED - Now using SamplerV2 (correct primitive for counts)
# ============================================================================================================================================
# Enter number of shots (default 32768): 32768
#
# Full search range : 0x4000 to 0x7fff
# ============================================================================================================================================
# Enter IBM Quantum API Token:
# Channel (ibm_quantum_platform or ibm_cloud) [ibm_quantum_platform]:
# qiskit_runtime_service._discover_account:WARNING:2026-04-05 01:07:50,422: Loading account with the given token. A saved account will not be used.
# qiskit_runtime_service.__init__:WARNING:2026-04-05 01:07:53,840: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: qffl-qdp. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# ✅ Connected to IBM Quantum
# qiskit_runtime_service.backends:WARNING:2026-04-05 01:07:54,416: Loading instance: qffl-qdp, plan: open
# qiskit_runtime_service.backends:WARNING:2026-04-05 01:07:55,903: Using instance: qffl-qdp, plan: open
# Using IBM backend: ibm_fez
# 📡 Using backend: ibm_fez
# 📡 Submitting job to backend: ibm_fez
# 2026-04-05 01:07:56,493 | ERROR | Could not load 'ibm_backend': cannot import name 'ProviderV1' from 'qiskit.providers' (/usr/local/lib/python3.12/dist-packages/qiskit/providers/__init__.py)
# 2026-04-05 01:07:56,495 | ERROR | Could not load 'ibm_dynamic_circuits': cannot import name 'ProviderV1' from 'qiskit.providers' (/usr/local/lib/python3.12/dist-packages/qiskit/providers/__init__.py)
# 2026-04-05 01:07:56,512 | ERROR | Could not load 'ibm_backend': cannot import name 'ProviderV1' from 'qiskit.providers' (/usr/local/lib/python3.12/dist-packages/qiskit/providers/__init__.py)
# 2026-04-05 01:07:56,513 | ERROR | Could not load 'ibm_dynamic_circuits': cannot import name 'ProviderV1' from 'qiskit.providers' (/usr/local/lib/python3.12/dist-packages/qiskit/providers/__init__.py)
# 2026-04-05 01:07:56,520 | INFO | Pass: ContainsInstruction - 0.01669 (ms)
# 2026-04-05 01:07:56,520 | INFO | Pass: UnitarySynthesis - 0.01478 (ms)
# 2026-04-05 01:07:56,521 | INFO | Pass: HighLevelSynthesis - 0.53668 (ms)
# 2026-04-05 01:07:56,521 | INFO | Pass: BasisTranslator - 0.13256 (ms)
# 2026-04-05 01:07:56,521 | INFO | Pass: ElidePermutations - 0.01144 (ms)
# 2026-04-05 01:07:56,521 | INFO | Pass: RemoveDiagonalGatesBeforeMeasure - 0.04148 (ms)
# 2026-04-05 01:07:56,522 | INFO | Pass: RemoveIdentityEquivalent - 0.07486 (ms)
# 2026-04-05 01:07:56,522 | INFO | Pass: InverseCancellation - 0.19932 (ms)
# 2026-04-05 01:07:56,522 | INFO | Pass: ContractIdleWiresInControlFlow - 0.00644 (ms)
# 2026-04-05 01:07:56,524 | INFO | Pass: CommutativeCancellation - 2.00176 (ms)
# 2026-04-05 01:07:56,527 | INFO | Pass: ConsolidateBlocks - 2.22182 (ms)
# 2026-04-05 01:07:56,527 | INFO | Pass: Split2QUnitaries - 0.01025 (ms)
# 2026-04-05 01:07:56,527 | INFO | Pass: SetLayout - 0.00834 (ms)
# 2026-04-05 01:07:56,528 | INFO | Pass: VF2Layout - 1.43003 (ms)
# 2026-04-05 01:07:56,528 | INFO | Pass: BarrierBeforeFinalMeasurements - 0.06318 (ms)
# 2026-04-05 01:07:57,250 | INFO | Pass: SabreLayout - 721.17162 (ms)
# 2026-04-05 01:07:57,250 | INFO | Pass: CheckMap - 0.18573 (ms)
# 2026-04-05 01:07:57,262 | INFO | Pass: VF2PostLayout - 11.20210 (ms)
# 2026-04-05 01:07:57,263 | INFO | Pass: ApplyLayout - 0.89550 (ms)
# 2026-04-05 01:07:57,263 | INFO | Pass: FilterOpNodes - 0.36669 (ms)
# 2026-04-05 01:07:57,263 | INFO | Pass: UnitarySynthesis - 0.01717 (ms)
# 2026-04-05 01:07:57,263 | INFO | Pass: HighLevelSynthesis - 0.15450 (ms)
# 2026-04-05 01:07:57,270 | INFO | Pass: BasisTranslator - 6.53005 (ms)
# 2026-04-05 01:07:57,271 | INFO | Pass: Depth - 1.24526 (ms)
# 2026-04-05 01:07:57,272 | INFO | Pass: Size - 0.01192 (ms)
# 2026-04-05 01:07:57,272 | INFO | Pass: MinimumPoint - 0.03266 (ms)
# 2026-04-05 01:07:57,280 | INFO | Pass: ConsolidateBlocks - 7.74717 (ms)
# 2026-04-05 01:07:57,292 | INFO | Pass: UnitarySynthesis - 12.60328 (ms)
# 2026-04-05 01:07:57,293 | INFO | Pass: RemoveIdentityEquivalent - 0.42439 (ms)
# 2026-04-05 01:07:57,298 | INFO | Pass: Optimize1qGatesDecomposition - 4.49634 (ms)
# 2026-04-05 01:07:57,303 | INFO | Pass: CommutativeCancellation - 5.28526 (ms)
# 2026-04-05 01:07:57,303 | INFO | Pass: ContractIdleWiresInControlFlow - 0.00715 (ms)
# 2026-04-05 01:07:57,304 | INFO | Pass: GatesInBasis - 0.61178 (ms)
# 2026-04-05 01:07:57,305 | INFO | Pass: Depth - 0.82350 (ms)
# 2026-04-05 01:07:57,305 | INFO | Pass: Size - 0.00739 (ms)
# 2026-04-05 01:07:57,306 | INFO | Pass: MinimumPoint - 0.75936 (ms)
# 2026-04-05 01:07:57,312 | INFO | Pass: ConsolidateBlocks - 6.18696 (ms)
# 2026-04-05 01:07:57,315 | INFO | Pass: UnitarySynthesis - 2.94876 (ms)
# 2026-04-05 01:07:57,316 | INFO | Pass: RemoveIdentityEquivalent - 0.14806 (ms)
# 2026-04-05 01:07:57,319 | INFO | Pass: Optimize1qGatesDecomposition - 2.72274 (ms)
# 2026-04-05 01:07:57,322 | INFO | Pass: CommutativeCancellation - 3.10087 (ms)
# 2026-04-05 01:07:57,322 | INFO | Pass: ContractIdleWiresInControlFlow - 0.00691 (ms)
# 2026-04-05 01:07:57,323 | INFO | Pass: GatesInBasis - 0.55075 (ms)
# 2026-04-05 01:07:57,324 | INFO | Pass: Depth - 0.72145 (ms)
# 2026-04-05 01:07:57,324 | INFO | Pass: Size - 0.00572 (ms)
# 2026-04-05 01:07:57,325 | INFO | Pass: MinimumPoint - 0.86188 (ms)
# 2026-04-05 01:07:57,331 | INFO | Pass: ConsolidateBlocks - 6.00314 (ms)
# 2026-04-05 01:07:57,334 | INFO | Pass: UnitarySynthesis - 2.98905 (ms)
# 2026-04-05 01:07:57,335 | INFO | Pass: RemoveIdentityEquivalent - 0.19193 (ms)
# 2026-04-05 01:07:57,337 | INFO | Pass: Optimize1qGatesDecomposition - 2.52318 (ms)
# 2026-04-05 01:07:57,341 | INFO | Pass: CommutativeCancellation - 3.02100 (ms)
# 2026-04-05 01:07:57,341 | INFO | Pass: ContractIdleWiresInControlFlow - 0.00620 (ms)
# 2026-04-05 01:07:57,341 | INFO | Pass: GatesInBasis - 0.55623 (ms)
# 2026-04-05 01:07:57,342 | INFO | Pass: Depth - 0.76795 (ms)
# 2026-04-05 01:07:57,342 | INFO | Pass: Size - 0.00763 (ms)
# 2026-04-05 01:07:57,343 | INFO | Pass: MinimumPoint - 0.87905 (ms)
# 2026-04-05 01:07:57,350 | INFO | Pass: ConsolidateBlocks - 6.32262 (ms)
# 2026-04-05 01:07:57,352 | INFO | Pass: UnitarySynthesis - 2.63309 (ms)
# 2026-04-05 01:07:57,353 | INFO | Pass: RemoveIdentityEquivalent - 0.18597 (ms)
# 2026-04-05 01:07:57,356 | INFO | Pass: Optimize1qGatesDecomposition - 2.57492 (ms)
# 2026-04-05 01:07:57,359 | INFO | Pass: CommutativeCancellation - 3.37076 (ms)
# 2026-04-05 01:07:57,359 | INFO | Pass: ContractIdleWiresInControlFlow - 0.00715 (ms)
# 2026-04-05 01:07:57,360 | INFO | Pass: GatesInBasis - 0.63848 (ms)
# 2026-04-05 01:07:57,361 | INFO | Pass: Depth - 0.75960 (ms)
# 2026-04-05 01:07:57,361 | INFO | Pass: Size - 0.00620 (ms)
# 2026-04-05 01:07:57,361 | INFO | Pass: MinimumPoint - 0.01502 (ms)
# 2026-04-05 01:07:57,367 | INFO | Pass: ConsolidateBlocks - 6.19721 (ms)
# 2026-04-05 01:07:57,370 | INFO | Pass: UnitarySynthesis - 2.56371 (ms)
# 2026-04-05 01:07:57,371 | INFO | Pass: RemoveIdentityEquivalent - 0.17333 (ms)
# 2026-04-05 01:07:57,374 | INFO | Pass: Optimize1qGatesDecomposition - 2.64740 (ms)
# 2026-04-05 01:07:57,377 | INFO | Pass: CommutativeCancellation - 3.34430 (ms)
# 2026-04-05 01:07:57,377 | INFO | Pass: ContractIdleWiresInControlFlow - 0.00715 (ms)
# 2026-04-05 01:07:57,378 | INFO | Pass: GatesInBasis - 0.65708 (ms)
# 2026-04-05 01:07:57,379 | INFO | Pass: Depth - 0.74100 (ms)
# 2026-04-05 01:07:57,379 | INFO | Pass: Size - 0.00572 (ms)
# 2026-04-05 01:07:57,379 | INFO | Pass: MinimumPoint - 0.01407 (ms)
# 2026-04-05 01:07:57,385 | INFO | Pass: ConsolidateBlocks - 6.33097 (ms)
# 2026-04-05 01:07:57,388 | INFO | Pass: UnitarySynthesis - 2.60997 (ms)
# 2026-04-05 01:07:57,389 | INFO | Pass: RemoveIdentityEquivalent - 0.17262 (ms)
# 2026-04-05 01:07:57,392 | INFO | Pass: Optimize1qGatesDecomposition - 2.62308 (ms)
# 2026-04-05 01:07:57,395 | INFO | Pass: CommutativeCancellation - 3.26371 (ms)
# 2026-04-05 01:07:57,395 | INFO | Pass: ContractIdleWiresInControlFlow - 0.00763 (ms)
# 2026-04-05 01:07:57,396 | INFO | Pass: GatesInBasis - 0.54359 (ms)
# 2026-04-05 01:07:57,397 | INFO | Pass: Depth - 0.74506 (ms)
# 2026-04-05 01:07:57,397 | INFO | Pass: Size - 0.00572 (ms)
# 2026-04-05 01:07:57,398 | INFO | Pass: MinimumPoint - 0.81038 (ms)
# 2026-04-05 01:07:57,405 | INFO | Pass: ConsolidateBlocks - 6.86574 (ms)
# 2026-04-05 01:07:57,407 | INFO | Pass: UnitarySynthesis - 2.63548 (ms)
# 2026-04-05 01:07:57,408 | INFO | Pass: RemoveIdentityEquivalent - 0.16212 (ms)
# 2026-04-05 01:07:57,411 | INFO | Pass: Optimize1qGatesDecomposition - 2.58875 (ms)
# 2026-04-05 01:07:57,414 | INFO | Pass: CommutativeCancellation - 3.35455 (ms)
# 2026-04-05 01:07:57,414 | INFO | Pass: ContractIdleWiresInControlFlow - 0.00715 (ms)
# 2026-04-05 01:07:57,415 | INFO | Pass: GatesInBasis - 0.55623 (ms)
# 2026-04-05 01:07:57,416 | INFO | Pass: Depth - 0.69952 (ms)
# 2026-04-05 01:07:57,416 | INFO | Pass: Size - 0.00596 (ms)
# 2026-04-05 01:07:57,417 | INFO | Pass: MinimumPoint - 0.81944 (ms)
# 2026-04-05 01:07:57,423 | INFO | Pass: ConsolidateBlocks - 6.46710 (ms)
# 2026-04-05 01:07:57,424 | INFO | Pass: UnitarySynthesis - 0.01621 (ms)
# 2026-04-05 01:07:57,424 | INFO | Pass: RemoveIdentityEquivalent - 0.16999 (ms)
# 2026-04-05 01:07:57,427 | INFO | Pass: Optimize1qGatesDecomposition - 2.95687 (ms)
# 2026-04-05 01:07:57,431 | INFO | Pass: CommutativeCancellation - 3.52097 (ms)
# 2026-04-05 01:07:57,431 | INFO | Pass: ContractIdleWiresInControlFlow - 0.02217 (ms)
# 2026-04-05 01:07:57,432 | INFO | Pass: GatesInBasis - 0.54979 (ms)
# 2026-04-05 01:07:57,432 | INFO | Pass: Depth - 0.77319 (ms)
# 2026-04-05 01:07:57,433 | INFO | Pass: Size - 0.00525 (ms)
# 2026-04-05 01:07:57,433 | INFO | Pass: MinimumPoint - 0.01574 (ms)
# 2026-04-05 01:07:57,434 | INFO | Pass: VF2PostLayout - 1.17779 (ms)
# 2026-04-05 01:07:57,434 | INFO | Pass: ContainsInstruction - 0.01955 (ms)
# 2026-04-05 01:07:57,434 | INFO | Pass: InstructionDurationCheck - 0.00787 (ms)
# Transpiled circuit depth: 1377
# Transpiled circuit size : 6442
#    Shots requested     : 32768
# base_primitive._run:INFO:2026-04-05 01:07:57,522: Submitting job using options {'options': {'default_shots': 32768, 'dynamical_decoupling': {'enable': True, 'sequence_type': 'XY4'}}, 'version': 2, 'support_qiskit': True}
#  Job ID: d78rbrik86tc739vk6p0
# ⏳ Waiting for results...
# Universal post-processing on 28533 measurements...
# Processing measurements: 100% 28533/28533 [00:03<00:00, 8270.17it/s]
#
# Verifying 5000 candidates from pure Shor's recovery...
#   0% 0/5000 [00:00<?, ?it/s]
# ============================================================================================================================================
# !!! PRIVATE KEY FOUND !!!
# Private key (hex): 0x405d
# Address          : 19hqK9vkcXRvnq6obsUaWSW6HywBHysot6
# ============================================================================================================================================
#   2% 92/5000 [00:00<00:02, 2040.43it/s]
#
# Execution finished.
